# %%
import glob
import dpkt
import numpy as np
import open3d as o3d

import pcap_parser.transforms as Tx
import pcap_parser.parse_pcap as utils
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
# list of pcap files in directory
# ---------------------------------------------------------------------------------------
PCAP_PATH='../data/ferry_pcap/'
pcap_files = glob.glob("{base}/*.pcap".format(base=PCAP_PATH))
file_path = pcap_files[1]
print(file_path)
# Out:
# ../data/ferry_pcap/lidar_00030_20211025155801_filtered.pcap

# %%
# Transformation

transformations = Tx.Compose([
    Tx.AxisRotate(
        axis=[0, 0, 1],
        angle=0.7070
        ),
    # Tx.PolygonCrop(polygon=[
    #         [0.0, -10.0],
    #         [-4.0, 0.0],
    #         [-4.0, 5.0],
    #         [-20.0, 10.0],
    #         [-20.0, -12.0],
    #         [0.0, -32.0]
    #     ]),
    Tx.Translate(x=5, y=-10)
])

# %%
with open(file_path, "rb") as f:
    
    packet_stream = dpkt.pcap.Reader(f)

    # feed the stream into cloud generator
    pc_generator = utils.yield_point_clouds(packet_stream)

    # do something with the clouds
    for i, point_cloud in enumerate(pc_generator):
        
        # print(pc.xyz.shape, pc.intensity.shape)
        point_cloud = transformations.apply(point_cloud)
        print(point_cloud.xyz.shape, point_cloud.intensity.shape)
        
        # print()
        point_cloud.data.astype(np.float32).tofile(f"data/cloud_{i}.bin")
        
        # pcd_data = pc.data.astype(np.float32)
        # pcd = o3d.geometry.PointCloud()
        # v3d = o3d.utility.Vector3dVector
        # pcd.points = v3d(pcd_data)
        # o3d.io.write.write_point_cloud(f"data/cloud_{i}.pcd", pcd)
# Out:
# (3992, 3) (3992, 1)
# (872, 3) (872, 1)
# (4160, 3) (4160, 1)
# (6030, 3) (6030, 1)
# (5028, 3) (5028, 1)
# (5038, 3) (5038, 1)
# (4992, 3) (4992, 1)
# (5491, 3) (5491, 1)
# (5296, 3) (5296, 1)
# (4518, 3) (4518, 1)
# (5269, 3) (5269, 1)
# (6374, 3) (6374, 1)
# (5674, 3) (5674, 1)
# (5199, 3) (5199, 1)
# (6305, 3) (6305, 1)
# (6310, 3) (6310, 1)
# (5384, 3) (5384, 1)
# (6879, 3) (6879, 1)
# (5646, 3) (5646, 1)
# (6238, 3) (6238, 1)
# (4924, 3) (4924, 1)
# (6733, 3) (6733, 1)
# (4979, 3) (4979, 1)
# (6169, 3) (6169, 1)
# (5158, 3) (5158, 1)
# (6110, 3) (6110, 1)
# (5198, 3) (5198, 1)
# (6195, 3) (6195, 1)
# (5762, 3) (5762, 1)
# (6105, 3) (6105, 1)
# (5213, 3) (5213, 1)
# (5319, 3) (5319, 1)
# (4786, 3) (4786, 1)
# (5888, 3) (5888, 1)
# (6861, 3) (6861, 1)
# (4376, 3) (4376, 1)
# (6853, 3) (6853, 1)
# (6103, 3) (6103, 1)
# (6915, 3) (6915, 1)
# (5688, 3) (5688, 1)
# (6391, 3) (6391, 1)
# (5773, 3) (5773, 1)
# (5735, 3) (5735, 1)
# (5674, 3) (5674, 1)
# (5101, 3) (5101, 1)
# (5748, 3) (5748, 1)
# (6784, 3) (6784, 1)
# (7279, 3) (7279, 1)
# (7176, 3) (7176, 1)
# (7282, 3) (7282, 1)
# (7266, 3) (7266, 1)
# (5835, 3) (5835, 1)
# (8142, 3) (8142, 1)
# (5340, 3) (5340, 1)
# (5556, 3) (5556, 1)
# (6357, 3) (6357, 1)
# (7072, 3) (7072, 1)
# (6490, 3) (6490, 1)
# (5997, 3) (5997, 1)
# (7088, 3) (7088, 1)
# (6498, 3) (6498, 1)
# (7055, 3) (7055, 1)
# (7857, 3) (7857, 1)
# (6872, 3) (6872, 1)
# (6908, 3) (6908, 1)
# (7980, 3) (7980, 1)
# (7876, 3) (7876, 1)
# (7150, 3) (7150, 1)
# (8042, 3) (8042, 1)
# (7812, 3) (7812, 1)
# (9026, 3) (9026, 1)
# (7879, 3) (7879, 1)
# (9068, 3) (9068, 1)
# (9067, 3) (9067, 1)
# (9004, 3) (9004, 1)
# (9045, 3) (9045, 1)
# (9034, 3) (9034, 1)
# (9017, 3) (9017, 1)
# (9058, 3) (9058, 1)
# (9033, 3) (9033, 1)
# (9048, 3) (9048, 1)
# (9013, 3) (9013, 1)
# (9056, 3) (9056, 1)
# (9010, 3) (9010, 1)
# (9040, 3) (9040, 1)
# (9049, 3) (9049, 1)
# (9022, 3) (9022, 1)
# (8960, 3) (8960, 1)
# (9018, 3) (9018, 1)
# (8991, 3) (8991, 1)
# (9013, 3) (9013, 1)
# (8946, 3) (8946, 1)
# (9015, 3) (9015, 1)
# (8986, 3) (8986, 1)
# (8970, 3) (8970, 1)
# (8971, 3) (8971, 1)
# (8973, 3) (8973, 1)
# (8952, 3) (8952, 1)
# (8909, 3) (8909, 1)
# (8952, 3) (8952, 1)
# (8921, 3) (8921, 1)
# (8917, 3) (8917, 1)
# (8924, 3) (8924, 1)
# (8933, 3) (8933, 1)
# (8889, 3) (8889, 1)
# (8896, 3) (8896, 1)
# (8913, 3) (8913, 1)
# (8916, 3) (8916, 1)
# (8878, 3) (8878, 1)
# (8864, 3) (8864, 1)
# (8860, 3) (8860, 1)
# (8851, 3) (8851, 1)
# (8840, 3) (8840, 1)
# (8848, 3) (8848, 1)
# (8832, 3) (8832, 1)
# (8842, 3) (8842, 1)
# (8825, 3) (8825, 1)
# (8810, 3) (8810, 1)
# (8836, 3) (8836, 1)
# (8808, 3) (8808, 1)
# (8835, 3) (8835, 1)
# (8801, 3) (8801, 1)
# (8853, 3) (8853, 1)
# (8805, 3) (8805, 1)
# (8809, 3) (8809, 1)
# (8776, 3) (8776, 1)
# (8782, 3) (8782, 1)
# (8799, 3) (8799, 1)
# (8763, 3) (8763, 1)
# (8801, 3) (8801, 1)
# (8802, 3) (8802, 1)
# (8737, 3) (8737, 1)
# (8747, 3) (8747, 1)
# (8751, 3) (8751, 1)
# (8741, 3) (8741, 1)
# (8735, 3) (8735, 1)
# (8757, 3) (8757, 1)
# (8731, 3) (8731, 1)
# (8742, 3) (8742, 1)
# (8729, 3) (8729, 1)
# (5507, 3) (5507, 1)
# (8780, 3) (8780, 1)
# (8762, 3) (8762, 1)
# (8740, 3) (8740, 1)
# (8772, 3) (8772, 1)
# (8764, 3) (8764, 1)
# (8785, 3) (8785, 1)
# (8788, 3) (8788, 1)
# (8785, 3) (8785, 1)
# (8794, 3) (8794, 1)
# (8794, 3) (8794, 1)
# (8795, 3) (8795, 1)
# (8766, 3) (8766, 1)
# (8781, 3) (8781, 1)
# (8776, 3) (8776, 1)
# (8805, 3) (8805, 1)
# (8771, 3) (8771, 1)
# (8789, 3) (8789, 1)
# (8804, 3) (8804, 1)
# (8794, 3) (8794, 1)
# (8824, 3) (8824, 1)
# (8794, 3) (8794, 1)
# (8781, 3) (8781, 1)
# (8785, 3) (8785, 1)
# (8789, 3) (8789, 1)
# (8787, 3) (8787, 1)
# (8778, 3) (8778, 1)
# (8792, 3) (8792, 1)
# (8790, 3) (8790, 1)
# (8789, 3) (8789, 1)
# (8799, 3) (8799, 1)
# (8770, 3) (8770, 1)
# (8776, 3) (8776, 1)
# (8758, 3) (8758, 1)
# (8782, 3) (8782, 1)
# (8775, 3) (8775, 1)
# (8754, 3) (8754, 1)
# (8753, 3) (8753, 1)
# (8761, 3) (8761, 1)
# (8785, 3) (8785, 1)
# (8791, 3) (8791, 1)
# (8395, 3) (8395, 1)
# (7426, 3) (7426, 1)
# (7193, 3) (7193, 1)
# (7246, 3) (7246, 1)
# (5665, 3) (5665, 1)
# (6933, 3) (6933, 1)
# (7724, 3) (7724, 1)
# (5533, 3) (5533, 1)
# (7629, 3) (7629, 1)
# (5750, 3) (5750, 1)
# (5200, 3) (5200, 1)
# (6643, 3) (6643, 1)
# (3588, 3) (3588, 1)
# (4295, 3) (4295, 1)
# (5568, 3) (5568, 1)
# (5518, 3) (5518, 1)
# (1627, 3) (1627, 1)
# (4677, 3) (4677, 1)
# (5422, 3) (5422, 1)
# (2771, 3) (2771, 1)
# (4098, 3) (4098, 1)
# (6929, 3) (6929, 1)
# (2128, 3) (2128, 1)
# (3966, 3) (3966, 1)
# (5413, 3) (5413, 1)
# (5146, 3) (5146, 1)
# (4930, 3) (4930, 1)
# (5472, 3) (5472, 1)
# (6092, 3) (6092, 1)
# (4803, 3) (4803, 1)
# (5696, 3) (5696, 1)
# (4504, 3) (4504, 1)
# (6105, 3) (6105, 1)
# (6115, 3) (6115, 1)
# (6107, 3) (6107, 1)
# (5844, 3) (5844, 1)
# (4246, 3) (4246, 1)
# (6866, 3) (6866, 1)
# (5620, 3) (5620, 1)
# (6553, 3) (6553, 1)
# (5540, 3) (5540, 1)
# (6323, 3) (6323, 1)
# (5834, 3) (5834, 1)
# (6878, 3) (6878, 1)
# (5359, 3) (5359, 1)
# (6738, 3) (6738, 1)
# (6169, 3) (6169, 1)
# (6194, 3) (6194, 1)
# (6158, 3) (6158, 1)
# (6386, 3) (6386, 1)
# (5769, 3) (5769, 1)
# (6442, 3) (6442, 1)
# (5127, 3) (5127, 1)
# (6236, 3) (6236, 1)
# (5974, 3) (5974, 1)
# (6446, 3) (6446, 1)
# (5830, 3) (5830, 1)
# (6135, 3) (6135, 1)
# (5231, 3) (5231, 1)
# (4054, 3) (4054, 1)
# (6984, 3) (6984, 1)
# (5201, 3) (5201, 1)
# (7103, 3) (7103, 1)
# (5678, 3) (5678, 1)
# (6020, 3) (6020, 1)
# (5840, 3) (5840, 1)
# (5544, 3) (5544, 1)
# (6922, 3) (6922, 1)
# (6919, 3) (6919, 1)
# (6283, 3) (6283, 1)
# (6582, 3) (6582, 1)
# (6327, 3) (6327, 1)
# (7187, 3) (7187, 1)
# (6283, 3) (6283, 1)
# (6934, 3) (6934, 1)
# (7296, 3) (7296, 1)
# (8396, 3) (8396, 1)
# (5476, 3) (5476, 1)
# (5478, 3) (5478, 1)
# (7506, 3) (7506, 1)
# (7030, 3) (7030, 1)
# (7043, 3) (7043, 1)
# (5546, 3) (5546, 1)
# (7625, 3) (7625, 1)
# (6893, 3) (6893, 1)
# (6894, 3) (6894, 1)
# (6419, 3) (6419, 1)
# (7267, 3) (7267, 1)
# (7547, 3) (7547, 1)
# (6489, 3) (6489, 1)
# (6599, 3) (6599, 1)
# (7083, 3) (7083, 1)
# (6497, 3) (6497, 1)
# (7081, 3) (7081, 1)
# (7331, 3) (7331, 1)
# (6618, 3) (6618, 1)
# (7022, 3) (7022, 1)
# (7198, 3) (7198, 1)
# (6587, 3) (6587, 1)
# (7385, 3) (7385, 1)
# (6983, 3) (6983, 1)
# (6613, 3) (6613, 1)
# (7032, 3) (7032, 1)
# (8630, 3) (8630, 1)
# (8734, 3) (8734, 1)
# (8782, 3) (8782, 1)
# (3617, 3) (3617, 1)
# (8794, 3) (8794, 1)
# (8768, 3) (8768, 1)
# (8762, 3) (8762, 1)
# (8790, 3) (8790, 1)
# (8780, 3) (8780, 1)
# (8760, 3) (8760, 1)
# (8766, 3) (8766, 1)
# (8757, 3) (8757, 1)
# (8751, 3) (8751, 1)
# (8788, 3) (8788, 1)
# (8793, 3) (8793, 1)
# (8803, 3) (8803, 1)
# (8764, 3) (8764, 1)
# (8760, 3) (8760, 1)
# (8756, 3) (8756, 1)
# (8775, 3) (8775, 1)
# (8751, 3) (8751, 1)
# (8728, 3) (8728, 1)
# (8567, 3) (8567, 1)
# (6414, 3) (6414, 1)
# (8711, 3) (8711, 1)
# (8737, 3) (8737, 1)
# (8730, 3) (8730, 1)
# (8720, 3) (8720, 1)
# (8702, 3) (8702, 1)
# (8727, 3) (8727, 1)
# (8703, 3) (8703, 1)
# (8726, 3) (8726, 1)
# (8726, 3) (8726, 1)
# (8715, 3) (8715, 1)
# (8726, 3) (8726, 1)
# (8706, 3) (8706, 1)
# (8113, 3) (8113, 1)
# (7226, 3) (7226, 1)
# (7036, 3) (7036, 1)
# (8693, 3) (8693, 1)
# (8709, 3) (8709, 1)
# (8692, 3) (8692, 1)
# (8703, 3) (8703, 1)
# (8710, 3) (8710, 1)
# (8701, 3) (8701, 1)
# (8717, 3) (8717, 1)
# (8695, 3) (8695, 1)
# (8702, 3) (8702, 1)
# (4482, 3) (4482, 1)
# (8625, 3) (8625, 1)
# (8699, 3) (8699, 1)
# (8678, 3) (8678, 1)
# (8674, 3) (8674, 1)
# (8678, 3) (8678, 1)
# (8661, 3) (8661, 1)
# (8697, 3) (8697, 1)
# (8669, 3) (8669, 1)
# (8694, 3) (8694, 1)
# (3565, 3) (3565, 1)
# (8610, 3) (8610, 1)
# (8687, 3) (8687, 1)
# (8722, 3) (8722, 1)
# (1428, 3) (1428, 1)
# (8389, 3) (8389, 1)
# (8700, 3) (8700, 1)
# (8699, 3) (8699, 1)
# (8697, 3) (8697, 1)
# (8694, 3) (8694, 1)
# (1439, 3) (1439, 1)

# %%
with open(file_path, "rb") as f:
    packet_stream = dpkt.pcap.Reader(f)

    # feed the stream into cloud generator
    pc_generator = utils.yield_point_clouds(packet_stream)

    # do something with the clouds
    for i, pc in enumerate(pc_generator):
        # pc = pipeline.apply(pc)
        # pc.data.astype(np.float32).tofile(f"data/cloud_{i}.bin")
        
        pcd_data = pc.data.astype(np.float32)
        pcd = o3d.geometry.PointCloud()
        v3d = o3d.utility.Vector3dVector
        pcd.points = v3d(pcd_data)
        o3d.io.write.write_point_cloud(f"data/cloud_{i}.pcd", pcd)
